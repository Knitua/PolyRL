csv")  # 替换为你的实际路径

# 添加序号列（从1开始）
df['Index'] = range(1, len(df) + 1)

# 计算累积最大score
df['Cumulative Max Score'] = df['score'].cummax()

# 设置x轴刻度：每隔2000个显示一次
max_index = df['Index'].max()
xticks_pos = np.arange(0, max_index + 1, 2000)
xticks_pos[0] = 1  # 保证起点为1，而不是0

# 绘图
plt.figure(figsize=(10, 5))
plt.plot(df['Index'], df['Cumulative Max Score'], linewidth=2)

# 设置x轴刻度
plt.xticks(ticks=xticks_pos)

# 坐标轴和标题
plt.xlabel("Molecule Index", fontsize=12)
plt.ylabel("Cumulative Max Score", fontsize=12)
plt.title("Cumulative Max Performance Trend", fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# 输出前10个最高score对应的分子信息
top10 = df.nlargest(10, 'score')[['Index', 'smiles', 'score']]
print("Top 10 molecules with highest scores and their index:")
print(top10.to_string(index=False))
# Out:
# Top 10 molecules with highest scores and their index:
#  Index                                                                   smiles    score
#   8620           *CC(*)C(COCC(COCCOCCC)COCCOCC(CC)CN)C(CO)OC(*)C(O)C(CO)C(OO)CO 3.856675
#   8893      *CC(CC(*)C(COCCOCC(CCC)CO)COCOC)COCCC(CBr)CC(CO)OC(SCl)C(CC)CC(*)Cl 3.845249
#   8970        *C(CC(COCC(CCC)C)C(CBr)COC)COC(CCOCBr)C(C*)C(COCC)COCC(CO)C(C*)Cl 3.838605
#   8798     *CC(OCC(*)COC(CCOCC)COC)COC(CO)C(CCl)C(C(CO)O)COC(CO)C(CC)COC(CCO)CO 3.809886
#   8980                 *CC(*)C(CC(*)COCCO)COCOCC(COC(CCC)C#C)COCC(CCCC)CCOC(*)O 3.807510
#  10024             *CC(C*)COCCC(CCOC(CCC)CC(Br)COCCO)COC(C)CCOC(C)C(C(C*)C#C)CO 3.791715
#   8738                    *CC(*)C(COCC(CO)COCCS)COCC(OCCC)C(CCC)COCC(*)C(CCO)SI 3.789262
#   8739           *CC(*)C(COCC(COCC)COC)COCOCC(CCOCC(CO)CO)OCOC(OCCC)C(C*)C(O)Cl 3.786136
#   8861 *CC(*)C(COCC(C)OCCOCC(CCO)CBr)OC(CCl)C(OCl)C(CC)COC(C)C(CCBr)COCC(*)COCO 3.785455
#   8616       *CC(*)C(COC)COCC(CO)C(CC)C(*)COCC(COCCO)OCC(OCCCl)OCOC(CC)C(CCC)CS 3.784744

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import numpy as np

# 设置字体为 Arial，防止负号乱码
rcParams['font.sans-serif'] = ['Arial']
rcParams['axes.unicode_minus'] = False

# 读取CSV文件
df = pd.read_csv("Reinforce+RF+A+300.csv")  # 替换为你的实际路径

# 添加序号列（从1开始）
df['Index'] = range(1, len(df) + 1)

# 计算累积最大score
df['Cumulative Max Score'] = df['score'].cummax()

# 设置x轴刻度：每隔2000个显示一次
max_index = df['Index'].max()
xticks_pos = np.arange(0, max_index + 1, 2000)
xticks_pos[0] = 1  # 保证起点为1，而不是0

# 绘图
plt.figure(figsize=(10, 5))
plt.plot(df['Index'], df['Cumulative Max Score'], linewidth=2)

# 设置x轴刻度
plt.xticks(ticks=xticks_pos)

# 坐标轴和标题
plt.xlabel("Molecule Index", fontsize=12)
plt.ylabel("Cumulative Max Score", fontsize=12)
plt.title("Cumulative Max Performance Trend", fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# 输出前10个最高score对应的分子信息
top10 = df.nlargest(10, 'score')[['Index', 'smiles', 'score']]
print("Top 10 molecules with highest scores and their index:")
print(top10.to_string(index=False))
# Out:
# Top 10 molecules with highest scores and their index:
#  Index                                                                       smiles    score
#  16443         */C=C/[Si](C)(C)[Si](C)(C)[Si](C)(*)C[Si](*)(C)[Si](C)(C)C1CCC(C)C1C 1.921341
#  19098       */N=N/[Si](C)(C)C[Si](C)(C)[Si](C)(*)[Si](C)(C)[Si](C)(C)C1C(*)CC(C)C1 1.921341
#  18886     */C=N/[Si](C)(C)[Si](C)(C)[Si](*)(C)[Si](C)(C)C[Si](C)(C)C1CCC(F)C(C)C1C 1.919002
#  16648       */N=N/[Si](C)(C)[Si](C)(*)C[Si](C)(C)[Si](C)(C)[Si](C)(C)C1CC(C)C(C)C1 1.918621
#  18253       */N=C/[Si](C)(C)[Si](*)(C)[Si](C)(C)[Si](C)(C)C[Si](C)(C)C1C(C)C(C)CC1 1.918621
#  18698 */N=N/[Si](C)(C)[Si](C)(C)C[Si](SC)(C)[Si](C)(*)[Si](C)(C)[Si]1CC(C)CC(*)C1C 1.918621
#  18732  */*=N/[Si](C)(C)[Si](*)(C)[Si](C)(C)[Si](C)(C)[Si](C)(C)C[Si]1CC(C)C(C)CC1O 1.918621
#  19138       */C=N/[Si](C)(C)[Si](C)(C)[Si](*)(C)C[Si](C)(C)C1C(C)CC([Si](C)(C)C)C1 1.918621
#  15501                      */N=N/[Si](C)(C)[Si](*)(C)C[Si](C)(C)C1CC(C)C(C)CC1[Si] 1.918273
#  15844                  */N=C/[Si](C)[Si](C)(C)[Si](F)(C)C[Si](C)(C)C1CCC(C)C(C)C1C 1.918273

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import numpy as np

# 设置字体为 Arial，防止负号乱码
rcParams['font.sans-serif'] = ['Arial']
rcParams['axes.unicode_minus'] = False

# 读取CSV文件
df = pd.read_csv("compounds2.csv")  # 替换为你的实际路径

# 添加序号列（从1开始）
df['Index'] = range(1, len(df) + 1)

# 计算累积最大score
df['Cumulative Max Score'] = df['score'].cummax()

# 设置x轴刻度：每隔2000个显示一次
max_index = df['Index'].max()
xticks_pos = np.arange(0, max_index + 1, 2000)
xticks_pos[0] = 1  # 保证起点为1，而不是0

# 绘图
plt.figure(figsize=(10, 5))
plt.plot(df['Index'], df['Cumulative Max Score'], linewidth=2)

# 设置x轴刻度
plt.xticks(ticks=xticks_pos)

# 坐标轴和标题
plt.xlabel("Molecule Index", fontsize=12)
plt.ylabel("Cumulative Max Score", fontsize=12)
plt.title("Cumulative Max Performance Trend", fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# 输出前10个最高score对应的分子信息
top10 = df.nlargest(10, 'score')[['Index', 'smiles', 'score']]
print("Top 10 molecules with highest scores and their index:")
print(top10.to_string(index=False))
# Out:
# Top 10 molecules with highest scores and their index:
#  Index                                                                                    smiles    score
#   1467     c1(O*)cc2c(cc1O*)C1(c3cc(C)c(C)cc3-c3cc4c(cc31)Oc1c(C#N)c(*)c(*)c(C#N)c1O4)c1ccccc1-2 1.885193
#   7660   c1c2c(cc(O*)c1O*)C1(c3c(cccc3)-c3cc4c(cc31)Oc1c(C#N)c(*)c(*)c(C#N)c1O4)c1c-2cc(C)c(C)c1 1.885193
#   7935     c1cccc2c1C1(c3cc(O*)c(O*)cc3-c3cc(C)c(C)cc31)c1c-2cc2c(c1)Oc1c(c(C#N)c(*)c(*)c1C#N)O2 1.885193
#   8422     c1c(O*)c(O*)cc2c1C1(c3cc(C)c(C)cc3-c3cc4c(cc31)Oc1c(c(C#N)c(*)c(*)c1C#N)O4)c1ccccc1-2 1.885193
#   9341 c1ccc2c(c1)C1(c3c-2cc2c(c3)Oc3c(c(C#N)c(*)c(*)c3C#N)O2)c2c(cc(O*)c(O*)c2)-c2cc(C)c(C)cc21 1.885193
#   9831   c12ccccc1-c1c(cc(O*)c(O*)c1)C21c2c(cc3c(c2)Oc2c(c(C#N)c(*)c(*)c2C#N)O3)-c2c1cc(C)c(C)c2 1.885193
#  10080   c12cc3c(cc1C1(c4cc(O*)c(O*)cc4-2)c2c(cccc2)-c2cc(C)c(C)cc21)Oc1c(C#N)c(*)c(*)c(C#N)c1O3 1.885193
#  10621   c1cccc2c1C1(c3c(cc(C)c(C)c3)-c3cc(O*)c(O*)cc31)c1c-2cc2c(c1)Oc1c(c(C#N)c(*)c(*)c1C#N)O2 1.885193
#  10662 c1(O*)c(O*)cc2c(c1)C1(c3c(cc(C)c(C)c3)-c3cc4c(cc31)Oc1c(C#N)c(*)c(*)c(C#N)c1O4)c1ccccc1-2 1.885193
#  10743 c1c2c(ccc1)-c1c(cc(O*)c(O*)c1)C21c2c(cc3c(c2)Oc2c(c(C#N)c(*)c(*)c2C#N)O3)-c2c1cc(C)c(C)c2 1.885193

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import numpy as np

# 设置字体为 Arial，防止负号乱码
rcParams['font.sans-serif'] = ['Arial']
rcParams['axes.unicode_minus'] = False

# 读取CSV文件
df = pd.read_csv("compounds2.csv")

# 添加分子索引
df['Index'] = range(1, len(df) + 1)

# 设置 batch 大小
batch_size = 128
num_batches = len(df) // batch_size

# 丢弃最后不足一个batch的部分（如你不想丢，可以改为 padding 或补0）
df_trimmed = df.iloc[:num_batches * batch_size].copy()

# 生成 batch ID
df_trimmed['Batch'] = df_trimmed.index // batch_size

# 每个 batch 求平均
batch_avg = df_trimmed.groupby('Batch')['score'].mean().reset_index()
batch_avg['Batch'] += 1  # Batch 从1开始计数

# 绘图
plt.figure(figsize=(7, 5))
plt.plot(batch_avg['Batch'], batch_avg['score'], linewidth=2, color='steelblue')

# 设置坐标轴
plt.xlabel("Batch Index (128 molecules per batch)", fontsize=12)
plt.ylabel("Average Score", fontsize=12)
plt.title("Average Score per Batch", fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
